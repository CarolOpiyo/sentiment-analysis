# %% [markdown]
# # Cyberbullying Detection on Social Media: A Natural Language Processing Approach.

# %% [markdown]
# **1. Introduction**
#
# *The Digital Age and the Rise of Social Media:*
#
# In the era of pervasive internet access, social media platforms have transformed into the cornerstone of modern communication. They serve as a breeding ground for connection, fostering the exchange of information and ideas on a global scale (Wallace, 2016).  Platforms like Facebook, Twitter, and Instagram have revolutionized the way we interact, allowing individuals to connect with friends, family, and even complete strangers across the globe.
#
# *The Darker Side: The Emergence of Cyberbullying*
#
# However, this interconnectedness has also cast a dark shadow, manifesting in the form of cyberbullying, a pervasive social ill with demonstrably severe psychological consequences (Hinduja & Patchin, 2010).  Cyberbullying refers to the use of electronic communication to bully a person, typically by sending messages of an intimidating or threatening nature (StopBullying.gov, 2021).
#
# *Amplifying the Problem: Anonymity and Reach of Social Media*
#
# Amplifying the detrimental effects of cyberbullying is the cloak of anonymity offered by the digital landscape. This emboldens perpetrators, allowing them to wield their cruelty with minimal repercussions. Furthermore, the vast reach of social media platforms magnifies the impact of bullying, subjecting victims to relentless harassment within a seemingly inescapable online sphere (Kowalski et al., 2014).  Unlike traditional bullying, which is often confined to a physical location, cyberbullying can transcend geographical boundaries and permeate every aspect of the victim's online life.
#
#
# **2. Problem Statement and Justification**
#
# Cyberbullying transcends geographical boundaries, plaguing individuals across all age groups. However, adolescents and young adults are especially vulnerable, often lacking the emotional resilience to navigate the complexities of online harassment (Li, 2017).  Research suggests that cyberbullying can lead to a myriad of negative consequences, including depression, anxiety, social isolation, and even suicidal ideation (Hinduja & Patchin, 2009).
#
# *Limitations of Traditional Methods*
#
# Traditional methods employed by social media platforms to combat cyberbullying, such as user reporting and reactive moderation, are demonstrably ineffective in stemming the tide of this issue.  These reactive approaches often fail to address the root cause and leave the victims grappling with the aftermath of the abuse.  Furthermore, the sheer volume of content uploaded to social media platforms daily makes it virtually impossible for human moderators to effectively monitor and identify all instances of cyberbullying.
#
# **Solution:**
#
# Therefore, a proactive solution is necessary to curb cyberbullying at its inception. This necessitates the development of sophisticated NLP-powered mechanisms capable of automatically detecting instances of cyberbullying within social media content.  Such a system would offer a scalable and efficient approach to safeguarding the digital space, fostering a more inclusive online environment.
#
# NLP refers to a subfield of Artificial Intelligence (AI) that deals with the interaction between computers and human language. NLP techniques can be effectively employed to analyze vast amounts of textual data and extract meaningful insights. In the context of cyberbullying detection, NLP can be harnessed to identify specific linguistic patterns and features indicative of bullying behavior.
#
# **3. Scope**
#
# This research adopts a platform-agnostic approach, aiming to develop a solution applicable across various social media platforms.  The primary focus lies on protecting vulnerable populations, particularly adolescents and young adults, who are demonstrably more susceptible to the harmful effects of cyberbullying.  Furthermore, the research prioritizes privacy preservation, ensuring that user data is protected throughout the analysis process.
#
# By demonstrating the feasibility and effectiveness of NLP in addressing cyberbullying, this study contributes significantly to our understanding of this pervasive issue in the digital age.  The research not only highlights the potential of NLP models for predictive detection but also paves the way for the creation of safer online communities for all users.
#
# **4. Data description**
#
# For my research, I utilized a dataset comprised of tweets, annotated as "bullying" or "non-bullying". This dataset includes the text of each tweet, its classification, and accompanying metadata such as timestamps and anonymized user IDs. The presence of such a dataset is crucial for training and evaluating the NLP model, providing a foundation that reflects the diverse and nuanced nature of language in cyberbullying instances. Analysis of this data revealed the complexity of cyberbullying, showcasing a wide range of linguistic expressions from overt aggression to subtle intimidation, underscoring the importance of advanced NLP techniques capable of understanding such nuances.
#
# **5. Hypothesis and Underlying Assumptions**
#
# This research is driven by the primary hypothesis that NLP can be effectively harnessed to identify and mitigate cyberbullying instances within social media content with a high degree of accuracy.  This hinges on the assumption that distinct linguistic patterns characteristic of cyberbullying can be computationally detected and distinguished from regular online interactions.
#
# Training an NLP model on a large and representative dataset, such as the one employed in this study, equips it with the ability to accurately classify social media content.  This approach not only underscores the potential of NLP as a proactive tool in combating cyberbullying but also emphasizes the significance of interdisciplinary efforts in fostering safer online environments.
#
# It is crucial to acknowledge the underlying assumptions of this research.  Firstly, it assumes the primary nature of cyberbullying manifests through textual content.  Secondly, it recognizes the inherent complexities of human language, encompassing the use of sarcasm and idioms, which can pose challenges for accurate interpretation.  Finally, the influence of cultural context on the perception of language is acknowledged.
#
# **6. Significance**
#
# "The ever-increasing prevalence of cyberbullying, particularly amongst adolescents, necessitates innovative solutions to address its detrimental effects.  Cyberbullying manifests through a complex web of linguistic expressions, ranging from overt aggression to veiled threats and even the use of sarcasm.  To tackle this challenge, my research leveraged a dataset of annotated tweets, meticulously classified as 'bullying' or 'non-bullying.' This dataset provided a rich foundation for training and evaluating an NLP model. Analyzing this data unveiled the multifaceted nature of cyberbullying language, highlighting the crucial role of advanced NLP techniques in capturing these subtle nuances."
#
# This study contributes to the broader understanding of cyberbullying in the digital age, offering evidence of the feasibility and effectiveness of NLP in addressing online harassment. By demonstrating the predictive capabilities of NLP models in detecting cyberbullying, this research underscores the potential for technology to foster more inclusive and safe online communities for all users, particularly vulnerable populations like adolescents and young adults.

# %%
# Installing Libraries
# !pip install spacy
# !pip install textblob
# !pip install nbconvert[webpdf]
# !pip install gradio
# !pip install transformers torch pandas
# !pip install --upgrade transformers datasets
# !pip install --upgrade urllib3
# !pip install --upgrade requests
# !pip install --upgrade botocore
# Out:
# Requirement already satisfied: spacy in c:\users\pc\anaconda3\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Collecting typer<0.10.0,>=0.3.0 (from spacy)
#   Obtaining dependency information for typer<0.10.0,>=0.3.0 from https://files.pythonhosted.org/packages/62/39/82c9d3e10979851847361d922a373bdfef4091020da7f893acfaf07c0225/typer-0.9.4-py3-none-any.whl.metadata
#   Using cached typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pc\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\pc\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\pc\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\pc\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\pc\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\pc\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\pc\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Using cached typer-0.9.4-py3-none-any.whl (45 kB)
# Installing collected packages: typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.12.3
#     Uninstalling typer-0.12.3:
#       Successfully uninstalled typer-0.12.3
# Successfully installed typer-0.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.28.3 requires typer<1.0,>=0.12; sys_platform != "emscripten", but you have typer 0.9.4 which is incompatible.
# Requirement already satisfied: textblob in c:\users\pc\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\pc\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\pc\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\pc\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pc\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\pc\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Requirement already satisfied: nbconvert[webpdf] in c:\users\pc\anaconda3\lib\site-packages (6.5.4)
# Requirement already satisfied: lxml in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (4.12.2)
# Requirement already satisfied: bleach in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (5.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (5.9.2)
# Requirement already satisfied: packaging in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (1.2.1)
# Requirement already satisfied: traitlets>=5.0 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (5.7.1)
# Requirement already satisfied: pyppeteer<1.1,>=1 in c:\users\pc\anaconda3\lib\site-packages (from nbconvert[webpdf]) (1.0.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert[webpdf]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\pc\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert[webpdf]) (305.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\pc\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert[webpdf]) (7.4.9)
# Requirement already satisfied: nest-asyncio in c:\users\pc\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert[webpdf]) (1.5.6)
# Requirement already satisfied: fastjsonschema in c:\users\pc\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert[webpdf]) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\pc\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert[webpdf]) (4.17.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\pc\anaconda3\lib\site-packages (from pyppeteer<1.1,>=1->nbconvert[webpdf]) (1.4.4)
# Requirement already satisfied: certifi>=2021 in c:\users\pc\anaconda3\lib\site-packages (from pyppeteer<1.1,>=1->nbconvert[webpdf]) (2024.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\pc\anaconda3\lib\site-packages (from pyppeteer<1.1,>=1->nbconvert[webpdf]) (6.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\pc\anaconda3\lib\site-packages (from pyppeteer<1.1,>=1->nbconvert[webpdf]) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\pc\anaconda3\lib\site-packages (from pyppeteer<1.1,>=1->nbconvert[webpdf]) (4.65.0)
# Collecting urllib3<2.0.0,>=1.25.8 (from pyppeteer<1.1,>=1->nbconvert[webpdf])
#   Obtaining dependency information for urllib3<2.0.0,>=1.25.8 from https://files.pythonhosted.org/packages/b0/53/aa91e163dcfd1e5b82d8a890ecf13314e3e149c05270cc644581f77f17fd/urllib3-1.26.18-py2.py3-none-any.whl.metadata
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\pc\anaconda3\lib\site-packages (from pyppeteer<1.1,>=1->nbconvert[webpdf]) (10.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pc\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert[webpdf]) (2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\pc\anaconda3\lib\site-packages (from bleach->nbconvert[webpdf]) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\pc\anaconda3\lib\site-packages (from bleach->nbconvert[webpdf]) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\pc\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer<1.1,>=1->nbconvert[webpdf]) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\pc\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert[webpdf]) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\pc\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert[webpdf]) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert[webpdf]) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\pc\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert[webpdf]) (23.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\pc\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert[webpdf]) (6.3.2)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer<1.1,>=1->nbconvert[webpdf]) (0.4.6)
# Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
# Successfully installed urllib3-1.26.18
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.28.3 requires typer<1.0,>=0.12; sys_platform != "emscripten", but you have typer 0.9.4 which is incompatible.
# gradio 4.28.3 requires urllib3~=2.0, but you have urllib3 1.26.18 which is incompatible.
# Requirement already satisfied: gradio in c:\users\pc\anaconda3\lib\site-packages (4.28.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.110.3)
# Requirement already satisfied: ffmpy in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (3.7.2)
# Requirement already satisfied: numpy~=1.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (3.10.1)
# Requirement already satisfied: packaging in c:\users\pc\anaconda3\lib\site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (10.0.1)
# Requirement already satisfied: pydantic>=2.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (2.7.1)
# Requirement already satisfied: pydub in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.4.2)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Obtaining dependency information for typer<1.0,>=0.12 from https://files.pythonhosted.org/packages/20/b5/11cf2e34fbb11b937e006286ab5b8cfd334fde1c8fa4dd7f491226931180/typer-0.12.3-py3-none-any.whl.metadata
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Collecting urllib3~=2.0 (from gradio)
#   Obtaining dependency information for urllib3~=2.0 from https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl.metadata
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\pc\anaconda3\lib\site-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\pc\anaconda3\lib\site-packages (from gradio-client==0.16.0->gradio) (2024.3.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users
/s eta 0:00:02
#    -------------------------------------- - 11.8/12.2 MB 352.0 kB/s eta 0:00:02
#    -------------------------------------- - 11.8/12.2 MB 352.6 kB/s eta 0:00:02
#    -------------------------------------- - 11.9/12.2 MB 354.7 kB/s eta 0:00:02
#    -------------------------------------- - 11.9/12.2 MB 354.1 kB/s eta 0:00:02
#    -------------------------------------- - 11.9/12.2 MB 354.9 kB/s eta 0:00:01
#    -------------------------------------- - 11.9/12.2 MB 355.6 kB/s eta 0:00:01
#    ---------------------------------------  11.9/12.2 MB 356.2 kB/s eta 0:00:01
#    ---------------------------------------  12.0/12.2 MB 357.6 kB/s eta 0:00:01
#    ---------------------------------------  12.0/12.2 MB 358.1 kB/s eta 0:00:01
#    ---------------------------------------  12.0/12.2 MB 359.5 kB/s eta 0:00:01
#    ---------------------------------------  12.0/12.2 MB 362.3 kB/s eta 0:00:01
#    ---------------------------------------  12.0/12.2 MB 362.1 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.2 MB 362.7 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.2 MB 363.9 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.2 MB 365.8 kB/s eta 0:00:01
#    ---------------------------------------  12.1/12.2 MB 365.8 kB/s eta 0:00:01
#    ---------------------------------------  12.2/12.2 MB 366.4 kB/s eta 0:00:01
#    ---------------------------------------  12.2/12.2 MB 367.2 kB/s eta 0:00:01
#    ---------------------------------------  12.2/12.2 MB 370.5 kB/s eta 0:00:01
#    ---------------------------------------  12.2/12.2 MB 370.7 kB/s eta 0:00:01
#    ---------------------------------------- 12.2/12.2 MB 370.6 kB/s eta 0:00:00
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.98
#     Uninstalling botocore-1.34.98:
#       Successfully uninstalled botocore-1.34.98
# Successfully installed botocore-1.34.105
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.34.105 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.3.1 which is incompatible.

# %% [markdown]
# ## Library Imports.

# %%
# Essential Libraries
import numpy as np
import pandas as pd

# Preprocessing
import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AlbertTokenizer, AlbertForSequenceClassification
from transformers import BertForSequenceClassification, Trainer, TrainingArguments, AdamW
from torch.utils.data import DataLoader, Dataset
import sentencepiece
from torch.nn.functional import cross_entropy


# Model Building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# Model Evaluation
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Model Deployment
import ipywidgets as widgets
from IPython.display import display
import joblib

# Utilities
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punkt')
# nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Data Loading and preprocessing

# %%
# Load the dataset
df = pd.read_csv('cyberbullying_tweets.csv')
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# ### Shape and Info on the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
df.shape
# Out:
# (47692, 2)

# %% [markdown]
# ### Handling Null Values

# %%
# Check for null values and handle them
df.isnull().sum()
#df.dropna(inplace=True)
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %% [markdown]
# ### Handling Duplicate Values

# %%
# Count the number of duplicate rows
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 36

# %%
# Remove duplicate entries
df.drop_duplicates(inplace=True)

# %%
# Defining stopwords set and initializing stemmer
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def clean_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    # Remove user mentions and hashtags
    text = re.sub(r'\@\w+|\#', '', text)
    # Remove emoticons and other non-text characters
    text = re.sub(r'[\U00010000-\U0010ffff]', '', text, flags=re.UNICODE)  # For emoticons or other non-text characters
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Tokenize text
    tokenized_text = word_tokenize(text)
    # Remove stop words and perform stemming
    filtered_text = [stemmer.stem(word) for word in tokenized_text if word not in stop_words]
    return " ".join(filtered_text)

# Apply the advanced cleaning function to your tweet text
df['cleaned_tweet_text'] = df['tweet_text'].apply(clean_text)
print(df[['tweet_text', 'cleaned_tweet_text']].head())
# Out:
#                                           tweet_text  \
# 0  In other words #katandandre, your food was cra...
# 1  Why is #aussietv so white? #MKR #theblock #ImA...
# 2  @XochitlSuckkks a classy whore? Or more red ve...
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...
# 4  @RudhoeEnglish This is an ISIS account pretend...
#
#                                   cleaned_tweet_text
# 0                 word katandandr food crapilici mkr
# 1  aussietv white mkr theblock imacelebrityau tod...
# 2                     classi whore red velvet cupcak
# 3  meh p thank head concern anoth angri dude twitter
# 4  isi account pretend kurdish account like islam...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Class Distributions

# %%
sns.countplot(x='cyberbullying_type', data=df)
plt.title('Distribution of Cyberbullying Types')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This bar chart categorizes texts based on the type of cyberbullying they represent (or if they are not cyberbullying). Each color represents a different category, such as gender, religion, age, and ethnicity. This visualization helps in understanding which types of cyberbullying are most prevalent.

# %% [markdown]
# ### Word Count

# %%
df['word_count'] = df['tweet_text'].apply(lambda x: len(x.split()))

sns.histplot(data=df, x='word_count', bins=30)
plt.title('Word Count Distribution')
plt.show()

# %% [markdown]
# This histogram displays how word count is distributed across documents or entries in the dataset. Most documents contain very few words, as seen by the high frequency at lower word counts.

# %% [markdown]
# ### Wordclouds

# %%
# Generate a word cloud image
wordcloud = WordCloud(
    stopwords=STOPWORDS,  # Define stopwords to exclude
    background_color='white',  # Set the background color of the word cloud
    width=800,  # Set the width of the word cloud image
    height=400  # Set the height of the word cloud image
).generate(' '.join(df['tweet_text']))  # Join all texts in the column into a single string for word cloud generation

# Display the generated word cloud image
plt.figure(figsize=(10, 5))  # Set the size of the figure containing the word cloud
plt.imshow(wordcloud, interpolation='bilinear')  # Display the word cloud image with bilinear interpolation for smoothing
plt.axis('off')  # Turn off the axis to only show the word cloud
plt.show()  # Show the plot

# %% [markdown]
# Focuses on words related to a specific topic (e.g., religion and extremism). The size of each word indicates its frequency of appearance in the texts. This visual representation helps to quickly grasp the most emphasized themes in the dataset.

# %%
# Generate a word cloud for cyberbullying tweets
bullying_text = ' '.join(df[df['cyberbullying_type'] != 'none']['cleaned_tweet_text'])
wordcloud = WordCloud(width=800, height=400).generate(bullying_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
def create_cloud(data):
    text = df[df['cyberbullying_type'] == data]
    text_cloud = " ".join(txt for txt in text['tweet_text'])
    cloud = WordCloud(collocations=False, background_color='white', width=800, height=400).generate(text_cloud)
    plt.figure(figsize=(10, 5)) 
    plt.imshow(cloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()


create_cloud('religion')

# %%
# Concatenate all tweet texts into a single string
all_text = ' '.join(df['tweet_text'].values)

# Split the text into individual words
words = all_text.split()
stop_words = set(stopwords.words('english'))
words = [word for word in words if not word in stop_words]

# Count the frequency of each word
word_counts = Counter(words)
top_words = word_counts.most_common(100)
top_words
# Out:
# [('I', 16033),
#  ('school', 6679),
#  ('like', 5246),
#  ('high', 4645),
#  ('dumb', 4384),
#  ('bullied', 4266),
#  ('RT', 4187),
#  ('people', 3792),
#  ('u', 3238),
#  ('rape', 3021),
#  ('fuck', 3019),
#  ('one', 2786),
#  ('bully', 2725),
#  ('gay', 2686),
#  ('&amp;', 2598),
#  ('The', 2522),
#  ('get', 2503),
#  ('You', 2477),
#  ('nigger', 2441),
#  ('ass', 2438),
#  ('girls', 2377),
#  ("I'm", 2316),
#  ('girl', 2271),
#  ('jokes', 2068),
#  ('know', 2021),
#  ('think', 1956),
#  ('would', 1954),
#  ('black', 1868),
#  ('white', 1639),
#  ('got', 1601),
#  ('say', 1511),
#  ('make', 1506),
#  ('FUCK', 1497),
#  ('call', 1480),
#  ('even', 1440),
#  ('Muslim', 1421),
#  ('called', 1419),
#  ('And', 1393),
#  ('Muslims', 1386),
#  ('-', 1366),
#  ('never', 1333),
#  ('see', 1329),
#  ('ur', 1307),
#  ('still', 1305),
#  ('go', 1299),
#  ('This', 1288),
#  ('want', 1275),
#  ('#MKR', 1269),
#  ('fucking', 1261),
#  ('A', 1260),
#  ('really', 1207),
#  ('If', 1206),
#  ('women', 1181),
#  ('joke', 1167),
#  ('Christian', 1162),
#  ('#mkr', 1146),
#  ('said', 1130),
#  ('right', 1127),
#  ('bitch', 1124),
#  ('support', 1119),
#  ('bullies', 1119),
#  ('hate', 1084),
#  ('shit', 1080),
#  ('But', 1054),
#  ('first', 1037),
#  ('idiot', 1036),
#  ('time', 1035),
#  ('woman', 998),
#  ('idiots', 992),
#  ('need', 983),
#  ('OBAMA,', 957),
#  ('going', 955),
#  ('made', 954),
#  ('don’t', 948),
#  ('anything', 944),
#  ('So', 940),
#  ('They', 916),
#  ('it.', 911),
#  ('good', 907),
#  ('also', 897),
#  ('love', 881),
#  ('It', 871),
#  ('back', 869),
#  ("can't", 852),
#  ('He', 850),
#  ('.', 844),
#  ('Islamic', 838),
#  ('way', 827),
#  ('What', 818),
#  ("It's", 803),
#  ('someone', 798),
#  ('We', 795),
#  ('always', 782),
#  ('much', 781),
#  ('many', 780),
#  ('every', 775),
#  ('saying', 764),
#  ('middle', 758),
#  ('female', 756),
#  ('mean', 754)]

# %%
# Create a bar chart of the most common words
top_words = word_counts.most_common(10) # Change the number to show more/less words
x_values = [word[0] for word in top_words]
y_values = [word[1] for word in top_words]
plt.bar(x_values, y_values)
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Most Commonly Used Words')
plt.show()

# %% [markdown]
# This bar chart shows the frequency of the most commonly used words in a dataset. The word "I" appears most frequently, followed by "school", "like", and so forth. This indicates which terms are predominant in the text data being analyzed.

# %% [markdown]
# ### Sentiment Analysis Plot

# %%
# Initialize VADER Sentiment Intensity Analyzer
sid = SentimentIntensityAnalyzer()

# Apply sentiment analysis to each text
# This generates a dictionary of scores (neg, neu, pos, compound) for each text
df['sentiments'] = df['tweet_text'].apply(lambda x: sid.polarity_scores(x))

# Extract the compound score from the sentiments dictionary
df['compound'] = df['sentiments'].apply(lambda score_dict: score_dict['compound'])

# Initialize the sentiment_type column to empty strings
df['sentiment_type'] = ''

# Categorize sentiment based on the compound score
df.loc[df.compound > 0, 'sentiment_type'] = 'POSITIVE'  # Set sentiment_type to 'POSITIVE' for compound scores > 0
df.loc[df.compound == 0, 'sentiment_type'] = 'NEUTRAL'  # Set sentiment_type to 'NEUTRAL' for compound scores == 0
df.loc[df.compound < 0, 'sentiment_type'] = 'NEGATIVE'  # Set sentiment_type to 'NEGATIVE' for compound scores < 0

# Visualize the distribution of sentiment types
plt.figure(figsize=(10, 6))
sns.countplot(x='sentiment_type', data=df, order=['POSITIVE', 'NEUTRAL', 'NEGATIVE'])
plt.title('Sentiment Analysis Plot')
plt.show()

# %% [markdown]
# This bar chart shows the distribution of sentiments (positive, neutral, negative) across texts in the dataset. It highlights that most of the texts have been classified as negative.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# We'll extract features from the text data using TF-IDF, a technique that reflects the importance of words to a document in a collection.

# %%
# Initialize TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(df['cleaned_tweet_text'])

# %% [markdown]
# ## Model Building and Evaluation

# %% [markdown]
# Using logistic regression and multinomial naive Bayes for this project offers simplicity, interpretability, and effectiveness. Logistic regression is great for straightforward classification tasks like determining if a social media post is cyberbullying or not. It's easy to understand and gives insights into which features contribute to the classification. Multinomial naive Bayes excels with text data, making it perfect for analyzing the language typically found in social media posts. By combining these methods, the project gains a powerful toolkit for accurately identifying cyberbullying behavior across different social media platforms.

# %% [markdown]
# ### 1. Logistic Regression Model

# %%
X = tfidf
y = df['cyberbullying_type']

# View feature names
print(tfidf_vectorizer.get_feature_names_out())
# Out:
# ['abl' 'abort' 'absolut' 'abt' 'abus' 'accept' 'account' 'accus' 'act'
#  'action' 'activ' 'actual' 'ad' 'add' 'admit' 'adult' 'af' 'affect'
#  'afraid' 'african' 'age' 'agenda' 'ago' 'agre' 'ah' 'aint' 'al' 'aliv'
#  'allah' 'allow' 'alon' 'alreadi' 'alway' 'amaz' 'america' 'american'
#  'amp' 'andr' 'angri' 'anim' 'announc' 'annoy' 'anoth' 'answer' 'anti'
#  'anymor' 'anyon' 'anyth' 'apolog' 'appar' 'appear' 'appreci' 'arab'
#  'area' 'arent' 'argu' 'argument' 'armi' 'articl' 'asian' 'ask' 'ass'
#  'assault' 'asshol' 'assum' 'attack' 'attent' 'aw' 'awar' 'away' 'awesom'
#  'babi' 'bad' 'ball' 'ban' 'base' 'basic' 'bc' 'beat' 'beauti' 'becam'
#  'becom' 'behavior' 'belief' 'believ' 'belong' 'best' 'bet' 'better'
#  'bibl' 'big' 'biggest' 'bigot' 'bit' 'bitch' 'black' 'blame'
#  'blameonenotal' 'blm' 'block' 'blond' 'bloodi' 'bodi' 'bomb' 'book'
#  'born' 'bother' 'bout' 'boy' 'brain' 'break' 'bring' 'bro' 'brother'
#  'brought' 'brown' 'brutal' 'bs' 'btw' 'bu' 'build' 'bull' 'bulli'
#  'bullshit' 'bunch' 'burn' 'busi' 'buy' 'bye' 'came' 'cancel' 'car' 'card'
#  'care' 'case' 'cat' 'caus' 'celebr' 'certain' 'chanc' 'chang' 'charact'
#  'check' 'child' 'children' 'china' 'chines' 'choic' 'choos' 'christian'
#  'church' 'citi' 'claim' 'class' 'clear' 'clearli' 'close' 'cloth' 'club'
#  'code' 'colin' 'colleagu' 'colleg' 'color' 'come' 'comedi' 'comedian'
#  'comment' 'commit' 'common' 'commun' 'compani' 'compar' 'complain'
#  'complet' 'concern' 'condemn' 'confus' 'congress' 'conserv' 'consid'
#  'constantli' 'continu' 'control' 'convers' 'convert' 'cook' 'cool' 'coon'
#  'cop' 'correct' 'countri' 'coupl' 'cours' 'cover' 'crack' 'cracker'
#  'crap' 'crazi' 'creat' 'cri' 'crime' 'crimin' 'critic' 'crush' 'cultur'
#  'cunt' 'current' 'cut' 'cute' 'cuz' 'cyber' 'cyru' 'da' 'dad' 'daesh'
#  'daili' 'damn' 'danger' 'dare' 'dark' 'date' 'daughter' 'day' 'dead'
#  'deal' 'dear' 'death' 'debat' 'decid' 'declar' 'defend' 'definit' 'dem'
#  'democrat' 'deni' 'deserv' 'destroy' 'di' 'dick' 'didnt' 'die' 'differ'
#  'direct' 'disagre' 'discuss' 'disgust' 'disrespect' 'dm' 'doesnt' 'dog'
#  'dont' 'doubt' 'dream' 'dress' 'drink' 'drive' 'drop' 'drug' 'dude'
#  'dumb' 'earli' 'earth' 'easi' 'eat' 'educ' 'elect' 'elementari' 'els'
#  'em' 'email' 'end' 'enemi' 'english' 'enjoy' 'entir' 'equal' 'especi'
#  'eu' 'everi' 'everybodi' 'everyday' 'everyon' 'everyth' 'evid' 'evil'
#  'ex' 'exactli' 'exampl' 'excus' 'exist' 'expect' 'experi' 'explain'
#  'expos' 'extrem' 'extremist' 'eye' 'face' 'facebook' 'fact' 'faggot'
#  'fail' 'fair' 'faith' 'fake' 'fall' 'fals' 'famili' 'fan' 'far' 'fat'
#  'father' 'favorit' 'fear' 'feel' 'felt' 'femal' 'femin' 'feminazi'
#  'feminist' 'fight' 'figur' 'final' 'fine' 'fit' 'fix' 'folk' 'follow'
#  'food' 'fool' 'footbal' 'forc' 'forev' 'forget' 'forgot' 'form' 'free'
#  'freedom' 'friend' 'fuck' 'fuckin' 'fun' 'fund' 'funni' 'futur' 'game'
#  'gamerg' 'gang' 'gave' 'gay' 'gender' 'gener' 'genocid' 'girl'
#  'girlfriend' 'given' 'glad' 'god' 'goe' 'gon' 'gone' 'good' 'got'
#  'govern' 'grade' 'graduat' 'great' 'grew' 'group' 'grow' 'grown' 'gt'
#  'guess' 'gun' 'guy' 'ha' 'hadith' 'haha' 'hahaha' 'hair' 'half' 'hand'
#  'handl' 'hang' 'happen' 'happi' 'harass' 'hard' 'harm' 'hate' 'hatr'
#  'havent' 'head' 'health' 'hear' 'heard' 'heart' 'hell' 'help' 'hero'
#  'hey' 'hi' 'hide' 'high' 'hilari' 'hindu' 'histori' 'hit' 'hoe' 'hold'
#  'holi' 'home' 'homophob' 'honestli' 'hope' 'horribl' 'hot' 'hour' 'hous'
#  'howev' 'huge' 'huh' 'human' 'hurt' 'husband' 'hypocrisi' 'hypocrit' 'id'
#  'idea' 'ideolog' 'idiot' 'idk' 'ignor' 'ill' 'im' 'imagin' 'import'
#  'incid' 'includ' 'india' 'indian' 'innoc' 'instant' 'instead' 'insult'
#  'intent' 'internet' 'involv' 'isi' 'islam' 'islamist' 'isnt' 'israel'
#  'issu' 'ive' 'jail' 'jesu' 'jew' 'jewish' 'jihad' 'jihadi' 'job' 'join'
#  'joke' 'judg' 'jump' 'junior' 'justic' 'justifi' 'kashmir' 'kashmiri'
#  'kat' 'kati' 'kept' 'kick' 'kid' 'kill' 'kind' 'kinda' 'knew' 'know'
#  'known' 'la' 'ladi' 'land' 'languag' 'late' 'later' 'laugh' 'law' 'lead'
#  'leader' 'learn' 'leav' 'left' 'legal' 'lesbian' 'let' 'level' 'lgbt'
#  'liar' 'liber' 'lie' 'life' 'light' 'like' 'lil' 'line' 'link' 'list'
#  'listen' 'liter' 'littl' 'live' 'lmao' 'lmfao' 'logic' 'lol' 'london'
#  'long' 'look' 'lose' 'lost' 'lot' 'love' 'low' 'lt' 'lunch' 'mad' 'main'
#  'major' 'make' 'male' 'man' 'manag' 'mani' 'marri' 'marriag' 'mask'
#  'matter' 'mayb' 'mean' 'meant' 'media' 'meet' 'member' 'men' 'mental'
#  'mention' 'messag' 'met' 'middl' 'miley' 'million' 'mind' 'minor' 'minut'
#  'misogynist' 'miss' 'mistak' 'mix' 'mkr' 'mock' 'model' 'modi' 'moham'
#  'mom' 'moment' 'money' 'month' 'moral' 'morn' 'moron' 'mosqu' 'mostli'
#  'mother' 'mouth' 'movi' 'mr' 'multipl' 'murder' 'music' 'muslim' 'na'
#  'nasti' 'nation' 'natur' 'nazi' 'nd' 'need' 'negro' 'nerd' 'new' 'news'
#  'nice' 'nigga' 'nigger' 'night' 'nikki' 'nobodi' 'non' 'normal' 'noth'
#  'notic' 'notsexist' 'number' 'nurs' 'obama' 'obvious' 'offend' 'offens'
#  'offic' 'oh' 'ok' 'okay' 'old' 'older' 'omg' 'onlin' 'open' 'opinion'
#  'oppress' 'order' 'organ' 'origin' 'outsid' 'outta' 'page' 'paid' 'pain'
#  'pakistan' 'pakistani' 'parent' 'parti' 'pass' 'past' 'pathet' 'pay'
#  'peac' 'pedophil' 'peopl' 'perfect' 'period' 'person' 'phone' 'photo'
#  'physic' 'pic' 'pick' 'pictur' 'piec' 'piss' 'pl' 'place' 'plan' 'play'
#  'player' 'pleas' 'plu' 'point' 'polic' 'polici' 'polit' 'poor' 'popul'
#  'popular' 'posit' 'possibl' 'post' 'power' 'ppl' 'practic' 'pray'
#  'preach' 'prefer' 'present' 'presid' 'pretend' 'pretti' 'primari'
#  'prison' 'privat' 'privileg' 'pro' 'probabl' 'problem' 'project' 'promot'
#  'proof' 'propaganda' 'prophet' 'protect' 'protest' 'proud' 'prove'
#  'provid' 'public' 'pull' 'punch' 'push' 'pussi' 'que' 'question' 'quit'
#  'quot' 'quran' 'race' 'racial' 'racism' 'racist' 'radic' 'rais' 'random'
#  'rape' 'rapist' 'rate' 'read' 'readi' 'real' 'realiti' 'realiz' 'realli'
#  'reason' 'receiv' 'recent' 'record' 'red' 'refer' 'refus' 'relat'
#  'relationship' 'religi' 'religion' 'rememb' 'remind' 'remov' 'repli'
#  'report' 'repres' 'republican' 'respect' 'respons' 'rest' 'restaur'
#  'retard' 'rich' 'ridicul' 'right' 'riot' 'room' 'round' 'rss' 'rt' 'ruin'
#  'rule' 'run' 'sad' 'safe' 'said' 'saudi' 'save' 'saw' 'say' 'scare'
#  'school' 'score' 'scream' 'se' 'season' 'second' 'secular' 'seen'
#  'select' 'self' 'sell' 'send' 'sens' 'sent' 'seriou' 'serv' 'set' 'sever'
#  'sex' 'sexism' 'sexist' 'sexual' 'shame' 'share' 'sharia' 'shit' 'shitti'
#  'shock' 'shoot' 'short' 'shot' 'shouldnt' 'shut' 'sick' 'sign' 'simpli'
#  'sinc' 'singl' 'sir' 'sister' 'sit' 'situat' 'skin' 'slave' 'slaveri'
#  'sleep' 'slur' 'slut' 'small' 'smart' 'smh' 'social' 'societi' 'soft'
#  'somebodi' 'someon' 'someth' 'sometim' 'son' 'song' 'soon' 'sorri' 'sort'
#  'sound' 'sourc' 'speak' 'special' 'specif' 'speech' 'sport' 'spread' 'st'
#  'stand' 'standard' 'start' 'state' 'statement' 'statu' 'stay' 'step'
#  'stereotyp' 'stick' 'stop' 'stori' 'straight' 'street' 'strong' 'student'
#  'stuff' 'stupid' 'suck' 'suffer' 'suggest' 'suicid' 'super' 'support'
#  'suppos' 'sure' 'surpris' 'swear' 'ta' 'taken' 'taliban' 'talk' 'tall'
#  'target' 'taught' 'teach' 'teacher' 'team' 'tech' 'teen' 'teenag' 'tell'
#  'term' 'terribl' 'terror' 'terrorist' 'text' 'tf' 'th' 'thank' 'theyr'
#  'theyv' 'thing' 'think' 'tho' 'thought' 'thousand' 'thread' 'threat'
#  'threaten' 'throw' 'till' 'time' 'tire' 'today' 'togeth' 'told'
#  'tomorrow' 'tonight' 'took' 'total' 'train' 'tran' 'trash' 'treat' 'tri'
#  'troll' 'troubl' 'true' 'truli' 'trump' 'trust' 'truth' 'turn' 'tv'
#  'tweet' 'twitter' 'type' 'ugli' 'uh' 'uk' 'understand' 'unit' 'unless'
#  'upset' 'ur' 'usa' 'use' 'usual' 'valu' 'vers' 'victim' 'video' 'view'
#  'violenc' 'violent' 'voic' 'vote' 'vs' 'wait' 'wake' 'walk' 'wan' 'want'
#  'war' 'wash' 'wasnt' 'watch' 'way' 'wayn' 'weak' 'wear' 'week' 'weight'
#  'weird' 'went' 'werent' 'whatev' 'white' 'wife' 'win' 'wing' 'wish' 'wit'
#  'woman' 'women' 'wonder' 'wont' 'word' 'work' 'world' 'worri' 'wors'
#  'worst' 'worth' 'wouldnt' 'wouldv' 'wow' 'write' 'wrong' 'wtf' 'ya'
#  'yall' 'yard' 'ye' 'yea' 'yeah' 'year' 'yo' 'youll' 'young' 'youv' 'yr']

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Training the Logistic Regression model on the Training set
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# #### Predictions

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %% [markdown]
# #### Accuracy Score

# %%
# Calculating the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy*100:.2f}%')
# Out:
# Accuracy: 81.46%

# %% [markdown]
# #### Confusion Matrix

# %%
# Generating the Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# This matrix shows how often each class was predicted correctly and how often it was mistaken for another class. For example, class 3 was correctly predicted 1162 times, but was often misclassified as class 4 (968 times).

# %% [markdown]
# #### Classification Report

# %%
# Generating the Classification Report
class_report = classification_report(y_test, y_pred)
print(class_report)
# Out:
#                      precision    recall  f1-score   support
#
#                 age       0.94      0.96      0.95      2356
#           ethnicity       0.98      0.97      0.97      2419
#              gender       0.89      0.82      0.85      2337
#   not_cyberbullying       0.61      0.48      0.54      2464
# other_cyberbullying       0.56      0.72      0.63      2353
#            religion       0.94      0.94      0.94      2368
#
#            accuracy                           0.81     14297
#           macro avg       0.82      0.82      0.82     14297
#        weighted avg       0.82      0.81      0.81     14297

# %% [markdown]
# This shows that the model achieves an accuracy of 81%, with average precision, recall, and F1-score across all categories also at 82%. These metrics collectively help us understand the effectiveness of our model in identifying and classifying different types of cyberbullying.

# %% [markdown]
# ### 2. Multinomial Naive Bayes Model

# %%
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# #### Predictions

# %%
# Predictions
y_pred_nb = nb_model.predict(X_test)

# %% [markdown]
# #### Accuracy Score

# %%
print("Multinomial Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
# Out:
# Multinomial Naive Bayes Accuracy: 0.7350493110442751

# %% [markdown]
# The Multinomial Naive Bayes model achieved an accuracy of 73.50%. This metric indicates that approximately 73 out of every 100 predictions made by the model are correct, reflecting its ability to classify data effectively within the scope of our analysis.

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n", classification_report(y_test, y_pred_nb))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#                 age       0.69      0.95      0.80      2356
#           ethnicity       0.87      0.89      0.88      2419
#              gender       0.84      0.77      0.81      2337
#   not_cyberbullying       0.60      0.38      0.47      2464
# other_cyberbullying       0.54      0.48      0.51      2353
#            religion       0.81      0.94      0.87      2368
#
#            accuracy                           0.74     14297
#           macro avg       0.73      0.74      0.72     14297
#        weighted avg       0.73      0.74      0.72     14297

# %% [markdown]
# The results above show that the model achieves an accuracy of 74%, with an average precision, recall, and F1-score across all categories around 74%

# %% [markdown]
# # Using Pipelines

# %% [markdown]
# ## Using TfidfVectorizer

# %% [markdown]
# ### Logistic Regression Model

# %%
# Defining X and y
X =  df['cleaned_tweet_text']
y = df['cyberbullying_type']

# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Creating the Pipeline for Logistic Regression
logistic_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('classifier', LogisticRegression(max_iter=1000))
])

# Training the model
logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %%
# Making predictions
y_pred = logistic_pipeline.predict(X_test)

# %%
# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Logistic Regression Accuracy: {accuracy*100:.2f}%')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Logistic Regression Confusion Matrix')
plt.show()

# Classification Report
class_report = classification_report(y_test, y_pred)
print("Logistic Regression Classification Report:\n", class_report)
# Out:
# Logistic Regression Accuracy: 81.95%
# Logistic Regression Classification Report:
#                       precision    recall  f1-score   support
#
#                 age       0.93      0.97      0.95      2398
#           ethnicity       0.97      0.97      0.97      2388
#              gender       0.91      0.83      0.87      2384
#   not_cyberbullying       0.58      0.55      0.56      2381
# other_cyberbullying       0.58      0.65      0.61      2347
#            religion       0.96      0.94      0.95      2399
#
#            accuracy                           0.82     14297
#           macro avg       0.82      0.82      0.82     14297
#        weighted avg       0.82      0.82      0.82     14297

# %% [markdown]
# This matrix shows the performance of a logistic regression model in classifying different classes (from 0 to 5). Each cell shows the number of predictions made by the model, where the rows represent the actual classes, and the columns represent the predicted classes. For instance, the model predicted class 0 correctly 2322 times but confused class 0 with class 5 three times.

# %% [markdown]
# ### Multinomial Naive Bayes Pipeline

# %%
# Multinomial Naive Bayes Pipeline
nb_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('nb_model', MultinomialNB())
])

# Fit the Multinomial Naive Bayes
nb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('nb_model', MultinomialNB())])

# %% [markdown]
# ####  Evaluation

# %%
y_pred_nb = nb_pipeline.predict(X_test)
print("Multinomial Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_nb))
# Out:
# Multinomial Naive Bayes Accuracy: 0.7420437854095264
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#                 age       0.70      0.98      0.82      2398
#           ethnicity       0.83      0.91      0.87      2388
#              gender       0.80      0.82      0.81      2384
#   not_cyberbullying       0.67      0.34      0.45      2381
# other_cyberbullying       0.62      0.41      0.50      2347
#            religion       0.75      0.97      0.85      2399
#
#            accuracy                           0.74     14297
#           macro avg       0.73      0.74      0.72     14297
#        weighted avg       0.73      0.74      0.72     14297

# %% [markdown]
#  From the above the logistic rfegression model performed better than the Multinomial Naive Bayes in both scenarios, whether by using pipelines or not therefore it shows that  Logistic Regression is a more robust choice for this classification task.

# %% [markdown]
# ## Using CountVectorizer

# %% [markdown]
# The CountVectorizer is specifically used in text processing, where it converts a collection of text documents into a matrix of token counts. This matrix serves as input for algorithms to analyze text data. Each entry in the matrix represents the frequency of a word in a given document, which helps in identifying the importance or relevance of words within the document.

# %% [markdown]
# ### Logistic Regression Pipeline

# %%
# Splitting dataset
X = df['cleaned_tweet_text']  
y = df['cyberbullying_type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Creating Logistic Regression Pipeline with CountVectorizer
logistic_pipeline_cv = Pipeline([
    ('count_vect', CountVectorizer(stop_words='english')),
    ('classifier', LogisticRegression(max_iter=1000))
])

# Fit the pipeline
logistic_pipeline_cv.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('count_vect', CountVectorizer(stop_words='english')),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %% [markdown]
# #### Evaluation

# %%
# Predict and evaluate
y_pred_log_cv = logistic_pipeline_cv.predict(X_test)
print("Logistic Regression with CountVectorizer Accuracy:", accuracy_score(y_test, y_pred_log_cv))
print("\nClassification Report:\n", classification_report(y_test, y_pred_log_cv))
# Out:
# Logistic Regression with CountVectorizer Accuracy: 0.8199622298384276
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#                 age       0.97      0.97      0.97      2398
#           ethnicity       0.98      0.97      0.98      2388
#              gender       0.90      0.84      0.87      2384
#   not_cyberbullying       0.57      0.53      0.55      2381
# other_cyberbullying       0.57      0.68      0.62      2347
#            religion       0.97      0.93      0.95      2399
#
#            accuracy                           0.82     14297
#           macro avg       0.83      0.82      0.82     14297
#        weighted avg       0.83      0.82      0.82     14297

# %% [markdown]
# The Logistic Regression model with CountVectorizer exhibits a strong ability to accurately classify specific types of cyberbullying, especially age, ethnicity, and religion-related instances. While it also showed improvements in identifying non-cyberbullying content and other forms of cyberbullying, these areas still present opportunities for further enhancement. The higher accuracy and more balanced performance across categories suggest that Logistic Regression is a more robust choice for this classification task.

# %% [markdown]
# ### Multinomial Naive Bayes Pipeline

# %%
# Creating Multinomial Naive Bayes Pipeline with CountVectorizer
nb_pipeline_cv = Pipeline([
    ('count_vect', CountVectorizer(stop_words='english')),
    ('nb_model', MultinomialNB())
])

# Fit the pipeline
nb_pipeline_cv.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('count_vect', CountVectorizer(stop_words='english')),
#                 ('nb_model', MultinomialNB())])

# %% [markdown]
# #### Evaluation

# %%
# Predict and evaluate
y_pred_nb_cv = nb_pipeline_cv.predict(X_test)
print("Multinomial Naive Bayes with CountVectorizer Accuracy:", accuracy_score(y_test, y_pred_nb_cv))
print("\nClassification Report:\n", classification_report(y_test, y_pred_nb_cv))
# Out:
# Multinomial Naive Bayes with CountVectorizer Accuracy: 0.7530950549066238
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#                 age       0.73      0.99      0.84      2398
#           ethnicity       0.83      0.93      0.88      2388
#              gender       0.82      0.82      0.82      2384
#   not_cyberbullying       0.68      0.35      0.47      2381
# other_cyberbullying       0.61      0.44      0.51      2347
#            religion       0.77      0.97      0.86      2399
#
#            accuracy                           0.75     14297
#           macro avg       0.74      0.75      0.73     14297
#        weighted avg       0.74      0.75      0.73     14297

# %% [markdown]
# The Multinomial Naive Bayes model, when used with CountVectorizer for feature extraction, achieved an overall accuracy of 75.30% in classifying texts into six categories: age, ethnicity, gender, not_cyberbullying, other_cyberbullying, and religion. This means that about 75 out of every 100 predictions made by the model were correct.

# %% [markdown]
# The Logistic Regression model paired with CountVectorizer achieved a higher overall accuracy of 81.99% compared to the Multinomial Naive Bayes model, indicating a more effective classification of the text into the six specified categories: age, ethnicity, gender, not_cyberbullying, other_cyberbullying, and religion.

# %% [markdown]
# ## Integrating BERT and ALBERT for sentiment analysis

# %%
# labels for binary classification
df['label'] = (df['cyberbullying_type'] != 'not_cyberbullying').astype(int)
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)

# %% [markdown]
# ### Tokenize Text Data

# %%
class TweetDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
            truncation=True
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
train_dataset = TweetDataset(train_df['tweet_text'].tolist(), train_df['label'].tolist(), tokenizer)
test_dataset = TweetDataset(test_df['tweet_text'].tolist(), test_df['label'].tolist(), tokenizer)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16)

# %% [markdown]
# ### Train BERT Model

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
model.to(device)
optimizer = AdamW(model.parameters(), lr=2e-5)

epochs = 4  # Number of training epochs
model.train()

for epoch in range(epochs):
    for batch in train_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(input_ids=batch['input_ids'], attention_mask=batch['attention_mask'], labels=batch['labels'])
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item()}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Bert Model Evaluation

# %%
model.eval()
total_acc = 0
for batch in test_loader:
    batch = {k: v.to(device) for k, v in batch.items()}
    with torch.no_grad():
        outputs = model(input_ids=batch['input_ids'], attention_mask=batch['attention_mask'])
    logits = outputs.logits
    predictions = torch.argmax(logits, dim=-1)
    accuracy = (predictions == batch['labels']).float().mean()
    total_acc += accuracy.item()

print(f"Test Accuracy: {total_acc / len(test_loader)}")

# %% [markdown]
# ## Model Deployment

# %% [markdown]
# We will use an Interactive Model Deployment with IPython Widgets and Joblib.
#
# This deployment strategy employs Joblib and IPython Widgets to efficiently operationalize a machine learning model within a Jupyter Notebook. Joblib is chosen for its proficiency in handling large numpy arrays efficiently, making it ideal for serializing and reloading the logistic regression pipeline. This ensures quick and reliable model storage and access. Meanwhile, IPython Widgets provide an interactive user interface directly in the notebook. This allows for real-time input and output, enabling immediate testing and feedback. This combination of Joblib and IPython Widgets facilitates seamless integration and rapid prototyping within the familiar Jupyter environment, making it an excellent choice for demonstrations and educational purposes.

# %%
# Save the pipeline to a file
joblib.dump(logistic_pipeline, 'logistic_pipeline.pkl')

# Load the pipeline back from the file
logistic_pipeline = joblib.load('logistic_pipeline.pkl')

# Use loaded file to make predictions
def predict_tweet(text):
    prediction = logistic_pipeline.predict([text])
    return prediction[0]

text = widgets.Textarea(
    value='Enter text here...',
    placeholder='Type something',
    description='Text:',
    disabled=False
)

button = widgets.Button(description="Predict")

output = widgets.Output()

def on_button_clicked(b):
    with output:
        output.clear_output()
        prediction = predict_tweet(text.value)
        print("Prediction:", prediction)

button.on_click(on_button_clicked)

display(text, button, output)

# %% [markdown]
# This is just a simple interface where users can type in a tweet, and it will display whether the tweet is considered cyberbullying and its specific type.

# %% [markdown]
# # Results and Discussion:

# %% [markdown]
# This analysis reveals that certain keywords and phrases are highly indicative of cyberbullying content. The sentiment analysis further highlights the negative tone prevalent in such instances. Among the models evaluated, Logistic Regression showed promising results in accurately detecting cyberbullying, with an accuracy of 82.02%.
#
# These findings underscore the potential of machine learning in assisting with the early detection of cyberbullying, which could be pivotal in preventative measures and support systems online.

# %% [markdown]
# # References

# %% [markdown]
# Hinduja, S., & Patchin, J. W. (2010). Bullying, cyberbullying, and the role of the bystander. American Behavioral Scientist, 53(2), 277-297.
#
# Kowalski, R. M., Giumetti, G. E., & Schroeder, L. E. (2014). Electronic bullying: Incidence and outcomes. Computers in Human Behavior, 30(1), 200-208.
#
# StopBullying.gov https://www.stopbullying.gov/. (2021, January 19).
#
# Wallace, P. M. (2016). The psychology of the internet. Routledge.
#
# Hinduja, S., & Patchin, J. W. (2009). Bullying beyond the schoolyard: Online threats and the need for collaborative solutions. The Journal of Adolescent Health, 45(1), S13-S20.
#
# Li, Q. (2017). Cyberbullying and its impact on adolescent mental health. Child and Adolescent Psychiatry and Mental Health, 11(1), 1-7.
